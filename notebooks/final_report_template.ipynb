# %% [markdown]
# # AIMS-ML Final Report Notebook
# This notebook summarizes simulation data generation, surrogate model training, and evaluation.

# %%
import pandas as pd
from aims_ml.ml import train_all_targets
from aims_ml.visualization import plot_model_comparison

# %%
df = pd.read_csv('data/sim_runs.csv')
df.head()

# %%
metrics = train_all_targets(df, artifacts_dir='artifacts')
metrics

# %%
plot_model_comparison(metrics, out_path='artifacts/model_comparison_rmse.png')
metrics.sort_values(['target', 'rmse'])

# %% [markdown]
# ## Add analysis
# - Where do models perform best/worst?
# - Which features dominate predictions?
# - What are physics limitations of the simulator?
